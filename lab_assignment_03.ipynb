# %% [markdown]
# <a href="https://colab.research.google.com/github/JayanthPrudhivi6/JayanthPrudhivi_INFO5502_Spring2022/blob/main/lab_assignment_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third Lab-assignment (02/10/2022, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points). Fomulate your domain problem: Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

Domain problem: 
- Here Domain problem is to explore the movie that have top IMDB rating.

- The Research Question is to scrap the movies data from the imdb website. 
   . Here we retrieve the top rated movies. 
   .So, we can analyse the movies based on its ratings whether it is good or bad.
 

Data needed to answer the questions:
The following attributes are required to answer the research question
. MovieName
. Ratings



We collected the data from the following link:https://www.imdb.com/chart/top/


Steps for collecting and saving the data:
- Here, We used web scraping technique to scrape the data.
- Web Scraping is done by using BeautifulSoup library from IMDB website which has multiple pages.
- We scrap through each page and retrieve information which is required.
- The MovieName,Ratings details are obtained from the HTML script which obtained after inspecting the page.
- We parse the details based on elements in the html code and then store the data in a csv format.
- The CSV format is the prepared data after webscraping.


'''
# Out:
# '\nPlease write you answer here:\n\nDomain problem: \n- Here Domain problem is to explore the movie that have top IMDB rating.\n\n- The Research Question is to scrap the movies data from the imdb website. \n   . Here we retrieve the top rated movies. \n   .So, we can analyse the movies based on its ratings whether it is good or bad.\n \n\nData needed to answer the questions:\nThe following attributes are required to answer the research question\n. MovieName\n. Ratings\n\n\n\nWe collected the data from the following link:https://www.imdb.com/chart/top/\n\n\nSteps for collecting and saving the data:\n- Here, We used web scraping technique to scrape the data.\n- Web Scraping is done by using BeautifulSoup library from IMDB website which has multiple pages.\n- We scrap through each page and retrieve information which is required.\n- The MovieName,Ratings details are obtained from the HTML script which obtained after inspecting the page.\n- We parse the details based on elements in the ht
# ...

# %% [markdown]
# Question 2 (10 points). Collect your data to answer the research problem: Write python code to collect 1000 data samples you discussed above.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.imdb.com/chart/top/"
page = requests.get(url)
page
soup = BeautifulSoup(page.content, "html.parser")

# %%
#print(soup.prettify)# to get a html clear page

# %%
# scrap movie names
scraped_movies = soup.find_all('td', class_='titleColumn')
scraped_movies
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  </td>, <td class="titleColumn">
#        2.
#        <a href="/title/tt0068646/" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">The Godfather</a>
#  <span class="secondaryInfo">(1972)</span>
#  </td>, <td class="titleColumn">
#        3.
#        <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
#  <span class="secondaryInfo">(2008)</span>
#  </td>, <td class="titleColumn">
#        4.
#        <a href="/title/tt0071562/" title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">The Godfather: Part II</a>
#  <span class="secondaryInfo">(1974)</span>
#  </td>, <td class="titleColumn">
#        5.
# ...

# %%
# parsing the movie names
movies = []
for movie in scraped_movies:
    movie = movie.get_text().replace('\n', "")
    movie = movie.strip(" ")
    movies.append(movie)
movies
# Out:
# ['1.      The Shawshank Redemption(1994)',
#  '2.      The Godfather(1972)',
#  '3.      The Dark Knight(2008)',
#  '4.      The Godfather: Part II(1974)',
#  '5.      12 Angry Men(1957)',
#  "6.      Schindler's List(1993)",
#  '7.      The Lord of the Rings: The Return of the King(2003)',
#  '8.      Pulp Fiction(1994)',
#  '9.      The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '10.      The Good, the Bad and the Ugly(1966)',
#  '11.      Forrest Gump(1994)',
#  '12.      Fight Club(1999)',
#  '13.      Inception(2010)',
#  '14.      The Lord of the Rings: The Two Towers(2002)',
#  '15.      Star Wars: Episode V - The Empire Strikes Back(1980)',
#  '16.      The Matrix(1999)',
#  '17.      Goodfellas(1990)',
#  "18.      One Flew Over the Cuckoo's Nest(1975)",
#  '19.      Se7en(1995)',
#  '20.      Seven Samurai(1954)',
#  "21.      It's a Wonderful Life(1946)",
#  '22.      The Silence of the Lambs(1991)',
#  '23.      Saving Private Ryan(1998)',
# ...

# %%
# scrapping rating for movies
scraped_ratings = soup.find_all('td', class_='ratingColumn imdbRating')
scraped_ratings
# Out:
# [<td class="ratingColumn imdbRating">
#  <strong title="9.2 based on 2,570,752 user ratings">9.2</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.2 based on 1,770,164 user ratings">9.2</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 2,536,633 user ratings">9.0</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 1,224,317 user ratings">9.0</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 759,225 user ratings">9.0</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,309,693 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,768,483 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,973,346 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
# ...

# %%
# parsing ratings
ratings = []
for rating in scraped_ratings:
    rating = rating.get_text().replace('\n', '')
    ratings.append(rating)
ratings
# Out:
# ['9.2',
#  '9.2',
#  '9.0',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
# ...

# %%
data = pd.DataFrame() #creating a data frame and adding Movie Names & Ratings columns into it.
data['Movie Names'] = movies
data['Ratings'] = ratings
data.head()
# Out:
#                               Movie Names Ratings
# 0  1.      The Shawshank Redemption(1994)     9.2
# 1             2.      The Godfather(1972)     9.2
# 2           3.      The Dark Knight(2008)     9.0
# 3    4.      The Godfather: Part II(1974)     9.0
# 4              5.      12 Angry Men(1957)     9.0

# %%
data.to_csv('IMDB Top Movies.csv', index=False) #storing the entire data into the csv file.

# %% [markdown]
# Question 3 (10 points). Understand the data quality: Search a second hand dataset (any dataset) from kaggle or other websites. Describe the data quality problem of the dataset and explain your strtegy to clean the data

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''Please write you answer here:

 I have choosen the dataset named SuperMarket sales data from Kaggle.
Dataset:
- Link: https://www.kaggle.com/aungpyaeap/supermarket-sales
- There are different attributes like date, Branch, Cogs and other attributes in the dataset.


Steps to Clean the data:
- we convert all the dates which are inappropriate dates.
- Dropping unnecessary rows in a DataFrame.
- Changing the index of a DataFrame.
- Using . str() methods to clean columns having numericals in place of strings.
- Using the DataFrame. applymap() function to clean the entire dataset, element-wise.
- Skipping unnecessary rows in a CSV file.Remove all the stopwords from the data.
- Remove special characters and unwanted spaces from the data.
- Check if there is any NULL or Blank values  in the data.
- If there is any imbalance, we use SMOTE technique to balance the data by performing over sampling and under sampling.
'''
# Out:
# 'Please write you answer here:\n\n I have choosen the dataset named SuperMarket sales data from Kaggle.\nDataset:\n- Link: https://www.kaggle.com/aungpyaeap/supermarket-sales\n- There are different attributes like date, Branch, Cogs and other attributes in the dataset.\n\n\nSteps to Clean the data:\n- we convert all the dates which are inappropriate dates.\n- Dropping unnecessary rows in a DataFrame.\n- Changing the index of a DataFrame.\n- Using . str() methods to clean columns having numericals in place of strings.\n- Using the DataFrame. applymap() function to clean the entire dataset, element-wise.\n- Skipping unnecessary rows in a CSV file.Remove all the stopwords from the data.\n- Remove special characters and unwanted spaces from the data.\n- Check if there is any NULL or Blank values  in the data.\n- If there is any imbalance, we use SMOTE technique to balance the data by performing over sampling and under sampling.\n'

# %% [markdown]
# Question 4 (20 points). Data cleaning: There are two datasets TwADR-L (from Twitter) and AskAPatient (Link: https://zenodo.org/record/55013#.YgU2NN-ZO4T) for medical concept
# normalization. However, the two datasets have serious data quality problems. Please read the introduction of the datasets and clean the two datasets by following the steps in the statement.
#
# In the original dataset, the TwADR-L had 48,057 training, 1,256 validation and 1,427 test examples. The test set (all
# test samples from 10 folds combined) consists of 765 unique phrases and 273 unique classes (medical concepts). The AskAPatient dataset contained 156,652 training, 7,926 validation, and 8,662 test examples. The entire test set (all test samples
# from 10 folds combined) consists of 3,749 unique phrases and 1,035 unique classes (medical concepts). The authors
# randomly split each dataset into ten equal folds, ran 10-fold cross validation and reported the accuracy averaged across the
# ten folds.
#
# We found that, in the original data set, many phrase-label pairs appeared multiple times within the same training data file
# and also across the training and test data sets in the same fold. In the AskAPatient data set, on average 35.82% of the test data overlapped with training data in the same fold. In the Twitter (TwADR-L) dataset, on average 8.62% of the test set had an overlap with the training data in the same fold. Having a large overlap between the training and the test data can potentially
# introduce bias in the model and contribute to high accuracy. It is not unlikely that the high model performance reported in the original paper may be triggered by the the large overlap between the training and test sets.
#
# Therefore to remove the bias, we further cleaned and recreated the training, validation, and test sets such that each
# phrase-label pair appears only once in the entire dataset (either in training, validation or test set).
#
# (1) First, we combined all examples in training, validation and test data from the original data set and then removed all
# duplicate phrase-label pairs (examples that have the same phrase and label pair and appear more than once in training/validation/test datasets). Table II shows the statistics of the new dataset (after removing duplicates). The Twitter data set had 3,157 unique phrase-label pairs and 2,220 unique labels (medical concepts) while 173 phrases had multiple labels (i.e., they were assigned to more than one label). Many concepts had only one example, and the concept that had the most number
# of examples had 36 phrases. On average, each concept had 1.42 examples. The AskAPatient data set had 4,496 unique phrase-label pairs, 1,036 unique labels while 26 phrases had multiple labels. Table III shows examples of phrases that had multiple labels. For example, ‘mad’ can be mapped to ‘anger’ or ‘rage’ and ‘sore’ can be mapped to ‘pain’ or ‘myalgia’.
#
# (2) Second, we remove all concepts that had less than five examples. The statistics of the final data are shown in Table IV.
#
# (3) Third, we divide all examples without multiple labels into random 10 folds such that each unique phrase-label pair
# appears once in one of the 10 test sets. We add the pairs with multiple labels into the training data. This final 10-folds
# dataset is used in all our experiments.
#
# (The original paper can be download on canvas)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import glob
final_res_df = pd.DataFrame() # final result data frame

# %%
# Using for loop,iterating through datasets TwADR-L,AskAPatient
for i in ['TwADR-L', 'AskAPatient']:
    res = {}  #creating res dictionary
    dframe = pd.DataFrame()        #Creating dataframe 'dframe'
    for path in glob.glob('/content/drive/MyDrive/datasets/{}/*.txt'.format(i)):
        data = pd.read_csv(path, sep = "\t", header = None, encoding= 'unicode_escape')
        dframe = dframe.append(data)
    dframe = dframe.reset_index(drop=True)   # Creating combined dataframe by combining each dataset text files.
    dframe['phrase_label'] = dframe[1] + " " + dframe[2]
    dframe.columns = ['id', 'labels', 'phrases', 'phrase-label']
    dframe = dframe.astype({"id": str})      # type casting the id column to str
    for columns in dframe.columns:           # converting all values to lower case
        dframe[columns] = dframe[columns].str.lower() 
    dframe = dframe.drop_duplicates('phrase-label')   # removing duplicate phrase-label pairs

                                                          
    res['Unique_phrases'] = len(dframe['phrases'].unique()) # Storing the resukts into the res dictionary
    res['Unique_labels'] = len(dframe['labels'].unique())
    res['Unique_phrase_label_pairs'] = dframe.shape[0]
    dframe1 = pd.DataFrame(dframe['phrases'].value_counts())
    res['Phrases with multiple labels'] = dframe1[dframe1['phrases'] > 1].shape[0]
    res['Mininum examples per label'] = dframe['labels'].value_counts().values.min()
    res['Maximum examples per label'] = dframe['labels'].value_counts().values.max()
    res['Average no of examples per label'] = round(dframe['labels'].value_counts().mean(), 2)
    final_res_df = final_res_df.append(res, ignore_index=True) #using res dictionary, appending the final_res_df dataframe


final_res_df = final_res_df.T
final_res_df.columns = ['TwADR-L', 'AskAPatient']

final_res_df
# Out:
#                                   TwADR-L  AskAPatient
# Unique_phrases                    2944.00      4470.00
# Unique_labels                     2220.00      1038.00
# Unique_phrase_label_pairs         3157.00      4507.00
# Phrases with multiple labels       173.00        35.00
# Mininum examples per label           1.00         1.00
# Maximum examples per label          36.00       141.00
# Average no of examples per label     1.42         4.34

# %%
import pandas as pd
import glob
final_res_df = pd.DataFrame()
# Using for loop,iterating through datasets TwADR-L,AskAPatient
for i in ['TwADR-L', 'AskAPatient']: 
    dframe = pd.DataFrame()
    res = {}  #creating res dictionary
    for path in glob.glob('/content/drive/MyDrive/datasets/{}/*.txt'.format(i)):
        data = pd.read_csv(path, sep = "\t", header = None, encoding= 'unicode_escape')# reading the data from the path having datasets.
        dframe = dframe.append(data)
    
    dframe = dframe.reset_index(drop=True) # Creating combined dataframe by combining each dataset text files.
    dframe['phrase_label'] = dframe[1] + " " + dframe[2]
    dframe.columns = ['id', 'labels', 'phrases', 'phrase-label']
    
    dframe = dframe.astype({"id": str}) # type casting the id column to str
   
    for columns in dframe.columns:      # converting all values to lower case
        dframe[columns] = dframe[columns].str.lower() 

 
    dframe = dframe.drop_duplicates('phrase-label') # removing duplicate phrase-label pairs
    index = []
    for i in range(dframe.shape[0]):
        if dframe['labels'].value_counts()[dframe.iloc[i]['labels']] < 5:
            index.append(i)

    # Dropping the labels that have the count less than 5.
    dframe.drop(dframe.index[index], inplace=True)
    res = {}
    res['Unique_phrases'] = len(dframe['phrases'].unique())# storing results of the table in dictionary 'res'
    res['Unique_labels'] = len(dframe['labels'].unique())
    res['Unique_phrase_label_pairs'] = dframe.shape[0]
    dframe1 = pd.DataFrame(dframe['phrases'].value_counts())
    res['Phrases with multiple labels'] = dframe1[dframe1['phrases'] > 1].shape[0]
    res['Minimum examples per label'] = dframe['labels'].value_counts().values.min()
    res['Maximum examples per label'] = dframe['labels'].value_counts().values.max()
    res['Average no of examples per label'] = round(dframe['labels'].value_counts().mean(), 2)
    final_res_df = final_res_df.append(res, ignore_index=True)  #using res dictionary, appending the final_res_df dataframe

final_res_df = final_res_df.T
final_res_df.columns = ['TwADR-L', 'AskAPatient']
final_res_df
# Out:
#                                   TwADR-L  AskAPatient
# Unique_phrases                     616.00      2665.00
# Unique_labels                       76.00       233.00
# Unique_phrase_label_pairs          721.00      2686.00
# Phrases with multiple labels        87.00        19.00
# Minimum examples per label           5.00         5.00
# Maximum examples per label          36.00       141.00
# Average no of examples per label     9.49        11.53
