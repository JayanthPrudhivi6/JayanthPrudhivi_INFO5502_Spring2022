# %% [markdown]
# <a href="https://colab.research.google.com/github/JayanthPrudhivi6/JayanthPrudhivi_INFO5502_Spring2022/blob/main/lab_assignment_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third Lab-assignment (02/10/2022, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points). Fomulate your domain problem: Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

Domain problem: 
- Here Domain problem is to explore the movie that have top IMDB rating.

- The Research Question is to scrap the movies data from the imdb website. 
   . Here we retrieve the top rated movies. 
   .So, we can analyse the movies based on its ratings whether it is good or bad.
 

Data needed to answer the questions:
The following attributes are required to answer the research question
. MovieName
. ReleaseYear
. Ratings
. RunTime


We collected the data from the following link: https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc&count=100&start=


Steps for collecting and saving the data:
- Here, We used web scraping technique to scrape the data.
- Web Scraping is done by using BeautifulSoup library from IMDB website which has multiple pages.
- We scrap through each page and retrieve information which is required.
- The MovieName,Ratings,ReleaseYear and Runtime details are obtained from the HTML script which obtained after inspecting the page.
- We parse the details based on elements in the html code and then store the data in a csv format.
- The xlsx format is the prepared data after webscraping.


'''

# %% [markdown]
# Question 2 (10 points). Collect your data to answer the research problem: Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

#importing BeautifulSoup,requests and pandas Libraries
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import csv

listValues=[] #creating a list to store the movie details

for i in range(0,10):  #giving range 1000 
  html_Text=requests.get('https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc&count=100&start='+str(i)+'01&ref_=adv_nxt').text
  soup=bs(html_Text,'lxml')  #parsing html using BeautifulSoup and lxml
  movies=soup.find_all('div',class_='lister-item mode-advanced')

  for movie in movies: 
    movieName=movie.find('span',class_='lister-item-index unbold text-primary').text+ movie.find('h3',class_='lister-item-header').a.text #Extracting movie name from page by filtering with the class 'lister-item-index unbold text-primary'
    releaseYear=movie.find('span',class_='lister-item-year text-muted unbold').text.replace('(','').replace(')','') #Extracting release year from page by filtering with the class 'lister-item-year text-muted unbold'
    runTime=movie.find('span',class_='runtime').text #Extracting run time from page by filtering with the class 'runtime'
    rating=movie.find('div',class_='inline-block ratings-imdb-rating').strong.text #Extracting rating from page by filtering with the class 'inline-block ratings-imdb-rating'
    listValues.append([movieName,releaseYear,runTime,rating]) #appending movieName,releaseYear,runTime and rating to the list

df=pd.DataFrame(listValues,columns=['MovieName','ReleaseYear','RunTime','Rating']) #creating a data frame using list which has all the movie details
print("Length of DataFrame:",len(df))
print(df.head(10).to_string(index=False))#displaying 10 top imdb movies.
df.to_excel('imdb.xlsx',index= False ,header = False)#1000 top imdb movies will be scrapped and saved into imdb.xlsx file
# Out:
# Length of DataFrame: 1000
#                                       MovieName ReleaseYear RunTime Rating
#                                      1.Jai Bhim        2021 164 min    9.3
#                      2.The Shawshank Redemption        1994 142 min    9.3
#                                 3.The Godfather        1972 175 min    9.2
#                               4.Soorarai Pottru        2020 153 min    9.1
#                               5.The Dark Knight        2008 152 min    9.0
#                        6.The Godfather: Part II        1974 202 min    9.0
#                                  7.12 Angry Men        1957  96 min    9.0
# 8.The Lord of the Rings: The Return of the King        2003 201 min    8.9
#                                  9.Pulp Fiction        1994 154 min    8.9
#                             10.Schindler's List        1993 195 min    8.9

# %% [markdown]
# Question 3 (10 points). Understand the data quality: Search a second hand dataset (any dataset) from kaggle or other websites. Describe the data quality problem of the dataset and explain your strtegy to clean the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''Please write you answer here:

 I have choosen the dataset named SuperMarket sales data from Kaggle.
Dataset:
- Link: https://www.kaggle.com/aungpyaeap/supermarket-sales
- There are different attributes like date, Branch, Cogs and other attributes in the dataset.


Steps to Clean the data:
- we convert all the dates which are inappropriate dates.
- Dropping unnecessary rows in a DataFrame.
- Changing the index of a DataFrame.
- Using . str() methods to clean columns having numericals in place of strings.
- Using the DataFrame. applymap() function to clean the entire dataset, element-wise.
- Skipping unnecessary rows in a CSV file.Remove all the stopwords from the data.
- Remove special characters and unwanted spaces from the data.
- Check if there is any NULL or Blank values  in the data.
- If there is any imbalance, we use SMOTE technique to balance the data by performing over sampling and under sampling.
'''

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Question 4 (20 points). Data cleaning: There are two datasets TwADR-L (from Twitter) and AskAPatient (Link: https://zenodo.org/record/55013#.YgU2NN-ZO4T) for medical concept
# normalization. However, the two datasets have serious data quality problems. Please read the introduction of the datasets and clean the two datasets by following the steps in the statement.
#
# In the original dataset, the TwADR-L had 48,057 training, 1,256 validation and 1,427 test examples. The test set (all
# test samples from 10 folds combined) consists of 765 unique phrases and 273 unique classes (medical concepts). The AskAPatient dataset contained 156,652 training, 7,926 validation, and 8,662 test examples. The entire test set (all test samples
# from 10 folds combined) consists of 3,749 unique phrases and 1,035 unique classes (medical concepts). The authors
# randomly split each dataset into ten equal folds, ran 10-fold cross validation and reported the accuracy averaged across the
# ten folds.
#
# We found that, in the original data set, many phrase-label pairs appeared multiple times within the same training data file
# and also across the training and test data sets in the same fold. In the AskAPatient data set, on average 35.82% of the test data overlapped with training data in the same fold. In the Twitter (TwADR-L) dataset, on average 8.62% of the test set had an overlap with the training data in the same fold. Having a large overlap between the training and the test data can potentially
# introduce bias in the model and contribute to high accuracy. It is not unlikely that the high model performance reported in the original paper may be triggered by the the large overlap between the training and test sets.
#
# Therefore to remove the bias, we further cleaned and recreated the training, validation, and test sets such that each
# phrase-label pair appears only once in the entire dataset (either in training, validation or test set).
#
# (1) First, we combined all examples in training, validation and test data from the original data set and then removed all
# duplicate phrase-label pairs (examples that have the same phrase and label pair and appear more than once in training/validation/test datasets). Table II shows the statistics of the new dataset (after removing duplicates). The Twitter data set had 3,157 unique phrase-label pairs and 2,220 unique labels (medical concepts) while 173 phrases had multiple labels (i.e., they were assigned to more than one label). Many concepts had only one example, and the concept that had the most number
# of examples had 36 phrases. On average, each concept had 1.42 examples. The AskAPatient data set had 4,496 unique phrase-label pairs, 1,036 unique labels while 26 phrases had multiple labels. Table III shows examples of phrases that had multiple labels. For example, ‘mad’ can be mapped to ‘anger’ or ‘rage’ and ‘sore’ can be mapped to ‘pain’ or ‘myalgia’.
#
# (2) Second, we remove all concepts that had less than five examples. The statistics of the final data are shown in Table IV.
#
# (3) Third, we divide all examples without multiple labels into random 10 folds such that each unique phrase-label pair
# appears once in one of the 10 test sets. We add the pairs with multiple labels into the training data. This final 10-folds
# dataset is used in all our experiments.
#
# (The original paper can be download on canvas)

# %%
# You code here (Please add comments in the code):
#(1).
import glob
import numpy as np
result_df =  pd.DataFrame()
# we iterate through both datasets 
for dataset in ['TwADR-L', 'AskAPatient']:
    result = {}
    df = pd.DataFrame()
    for filepath in glob.glob('//content/drive/MyDrive/datasets/{}/*.txt'.format(dataset)):
        data = pd.read_csv(filepath, sep = "\t", header = None, encoding= 'unicode_escape')
        df = df.append(data)
    # we create combined dataframe by combining Each dataset text files.
    df = df.reset_index(drop=True)
    df['phrase_label'] = df[1] + " " + df[2]
    df.columns = ['id', 'labels', 'phrases', 'phrase-label']
    # type casting to str
    df = df.astype({"id": str})
    # converting all values to lower case
    for columns in df.columns:
        df[columns] = df[columns].str.lower() 

    # dropping duplicates
    df = df.drop_duplicates('phrase-label')

    # storing results of the table in dictionary
    result['Unique_phrases'] = len(df['phrases'].unique())
    result['Unique_labels'] = len(df['labels'].unique())
    result['Unique_phrase_label_pairs'] = df.shape[0]
    df1 = pd.DataFrame(df['phrases'].value_counts())
    result['Phrases with multiple labels'] = df1[df1['phrases'] > 1].shape[0]
    result['Min examples per label'] = df['labels'].value_counts().values.min()
    result['Max examples per label'] = df['labels'].value_counts().values.max()
    result['Avg examples per label'] = round(df['labels'].value_counts().mean(), 2)
    result_df = result_df.append(result, ignore_index=True)
    


result_df = result_df.T
result_df = result_df.astype({0: int, 1: int})
result_df.columns = ['TwADR-L', 'AskAPatient']

result_df
# Out:
#                               TwADR-L  AskAPatient
# Unique_phrases                   2944         4470
# Unique_labels                    2220         1038
# Unique_phrase_label_pairs        3157         4507
# Phrases with multiple labels      173           35
# Min examples per label              1            1
# Max examples per label             36          141
# Avg examples per label              1            4

# %%
from numpy.ma.core import resize
#(2) Second, we remove all concepts that had less than five examples. The statistics of the final data are shown in Table IV.
import pandas as pd
import glob
result_df = pd.DataFrame()
# Here, we iterate through both datasets 
for dataset in ['TwADR-L', 'AskAPatient']:
    df = pd.DataFrame()
    result = {}
    for filepath in glob.glob('/content/drive/MyDrive/datasets/{}/*.txt'.format(dataset)):
        #print(filepath)
        data = pd.read_csv(filepath, sep = "\t", header = None, encoding= 'unicode_escape')
        df = df.append(data)
    # we create combined dataframe by combining Each dataset by text files.
    df = df.reset_index(drop=True)
    df['phrase_label'] = df[1] + " " + df[2]
    df.columns = ['id', 'labels', 'phrases', 'phrase-label']
    #print(df.shape)
    df = df.astype({"id": str})
    # converting to lower case
    for columns in df.columns:
        df[columns] = df[columns].str.lower() 

    # we drop duplicates that are phrase-label pairs... 
    df = df.drop_duplicates('phrase-label')

    index_list = []
    for i in range(df.shape[0]):
        if df['labels'].value_counts()[df.iloc[i]['labels']] < 5:
            index_list.append(i)

    # we drop the labels that have less than count of 5.
    df.drop(df.index[index_list], inplace=True)
    result = {}
    # storing results of the table in dictionary
    result['Unique_phrases'] = len(df['phrases'].unique())
    result['Unique_labels'] = len(df['labels'].unique())
    result['Unique_phrase_label_pairs'] = df.shape[0]
    df1 = pd.DataFrame(df['phrases'].value_counts())
    result['Phrases with multiple labels'] = df1[df1['phrases'] > 1].shape[0]
    result['Min examples per label'] = df['labels'].value_counts().values.min()
    result['Max examples per label'] = df['labels'].value_counts().values.max()
    result['Avg examples per label'] = round(df['labels'].value_counts().mean(), 2)
    # appending the dictionary to dataframe
    result_df = result_df.append(result, ignore_index=True)
    #3)
    print("Result For Question 3 ")
    print(np.array_split(df,10))
result_df = result_df.T
#result_df = result_df.astype({0: str, 1: str})
result_df.columns = ['TwADR-L', 'AskAPatient']
print("Result for Question 2")

result_df
# Out:
# Result For Question 3
# [           id  ...                                       phrase-label
# 0    c0043012  ...                                wakefulness wake up
# 1    c0424295  ...  hyperactive behavior unnecessarily wipe for 20...
# 3    c0034634  ...                                         rage angry
# 4    c0043094  ...                                 weight gain 10+lbs
# 5    c0027497  ...                                       nausea dizzy
# ..        ...  ...                                                ...
# 101  c0018524  ...               hallucinations 1pm to 3am real quick
# 102  c0022107  ...                  irritable mood resting bitch face
# 103  c0018524  ...            hallucinations permanent hallucinations
# 104  c0015672  ...                                      fatigue tired
# 105  c0039971  ...                                         thirst dry
#
# [73 rows x 4 columns],             id  ...                               phrase-label
# 106   c0040822  ...                             tremor shaking
# 108   c0013144  ...                 drowsiness ready for a nap
# 109   c0027497  ...                                nausea sick
# 110   c0278061  ...          abnormal mental state fucks me up
# 111   c0235169  ...                excitability in my feelings
# ...        ...  ...                                        ...
# 2056  c0344315  ...              depressed mood depressed mood
# 2087  c0270458  ...  psychotic depression psychotic depression
# 2137  c0553668  ...        labored breathing labored breathing
# 2146  c0043012  ...                    wakefulness wakefulness
# 2162  c0220870  ...            lightheadedness lightheadedness
#
# [72 rows x 4 columns],             id  ...                                       phrase-label
# 2188  c0556446  ...                          drug craving drug craving
# 2217  c0041671  ...  attention deficit disorder attention deficit d...
# 2261  c0455769  ...                  energy increased energy increased
# 2263  c0278061  ...        abnormal mental state abnormal mental state
# 2282  c0596170  ...        binge eating disorder binge eating disorder
# ...        ...  ...                                                ...
# 2733  c0011570  ...                       mental depression depression
# 2736  c0233514  ...                abnormal behavior act fucking weird
# 2740  c0022107  ...         irritable mood pissed off about everything
# 2751  c0003467  ...            anxiety makes me question my whole life
# 2753  c0005586  ...                          bipolar disorder #bipolar
#
# [72 rows x 4 columns],             id  ...                                   phrase-label
# 2756  c0541854  ...          daytime sleepiness sleep the day away
# 2758  c0022107  ...                      irritable mood pissed off
# 2760  c0344315  ...                         depressed mood depress
# 2769  c0087169  ...                 withdrawal symptoms withdrawal
# 2775  c0022107  ...                       irritable mood sour mood
# ...        ...  ...                                            ...
# 3052  c0917801  ...                   sleeplessness sleep-deprived
# 3054  c0235146  ...                       euphoric mood feel great
# 3065  c0043012  ...                wakefulness makes me more awake
# 3067  c0455769  ...                     energy increased energetic
# 3075  c0600104  ...  obsessive compulsive behavior neat freak mode
#
# [72 rows x 4 columns],             id  ...                                   phrase-label
# 3079  c0004936  ...                mental disorders mental illness
# 3085  c0041671  ...  attention deficit disorder completely useless
# 3087  c0233514  ...           abnormal behavior behaviour problems
# 3099  c0011551  ...                       depersonalization zombie
# 3113  c0002957  ...                            anger got me pissed
# ...        ...  ...                                            ...
# 3418  c0455769  ...                     energy increased jacked up
# 3424  c0917801  ...              sleeplessness thinking it was 8pm
# 3444  c0011551  ...  depersonalization makes me a different person
# 3450  c2939186  ...      disturbance in mood about to lose my mind
# 3452  c0278061  ...          abnormal mental state bazaar thoughts
#
# [72 rows x 4 columns],             id  ...                                       phrase-label
# 3456  c2830004  ...                               somnolence so sleepy
# 3472  c0013146  ...  drug abuse 30-day adderall supply lasts me lik...
# 3474  c0013146  ...                           drug abuse double downed
# 3478  c0424295  ...     hyperactive behavior walking up and down broad
# 3486  c0278061  ...             abnormal mental state different person
# ...        ...  ...                                                ...
# 3858  c0497364  ...                                localized rash rash
# 3860  c0917801  ...                                sleeplessness awake
# 3871  c0278061  ...                        abnormal mental state crazy
# 3878  c0041671  ...              attention deficit disorder distracted
# 3890  c0152128  ...                drug withdrawal syndrome withdrawal
#
# [72 rows x 4 columns],             id  ...                                       phrase-label
# 3892  c0085632  ...                            indifferent mood apathy
# 3894  c0234428  ...            consciousness abnormal focusing monster
# 3901  c0038999  ...        swelling a general discomfort from swelling
# 3905  c0040822  ...                                  tremor brain zaps
# 3917  c1971624  ...              loss of appetite (finding) not hungry
# ...        ...  ...                                                ...
# 4326  c0556446  ...                    drug craving hooked on adderall
# 4334  c0232462  ...                    decrease in appetite not eating
# 4341  c0022107  ...                            irritable mood bad mood
# 4343  c1510472  ...  drug dependence i've been feeling better every...
# 4345  c0027497  ...                                       nausea spins
#
# [72 rows x 4 columns],             id  ...                                       phrase-label
# 4353  c0858899  ...  attention concentration difficulty expense of ...
# 4357  c0424166  ...                           social fear freaking out
# 4361  c2830004  ...                                   somnolence awake
# 4369  c0022107  ...                             irritable mood rantful
# 4371  c0043094  ...        weight gain moon face and 30 lbs in 6 weeks
# ...        ...  ...                                                ...
# 4676  c0011570  ...                       mental depression depressive
# 4680  c0018524  ...                     hallucinations bazaar thoughts
# 4692  c0027497  ...                              nausea wanted to vent
# 4696  c0034634  ...                                           rage mad
# 4702  c0424295  ...                   hyperactive behavior has me like
#
# [72 rows x 4 columns],             id  ...                                    phrase-label
# 4704  c0235169  ...              excitability got me in my feelings
# 4710  c0393760  ...                   initial insomnia i cant sleep
# 4712  c0232462  ...      decrease in appetite full off of a cracker
# 4716  c0393760  ...                     initial insomnia wide awake
# 4718  c0152128  ...    drug withdrawal syndrome withdrawal symptoms
# ...        ...  ...                                             ...
# 4979  c0728899  ...                          intoxication fucked up
# 4980  c0022107  ...                            irritable mood angry
# 4991  c0917801  ...                     sleeplessness want to sleep
# 4993  c0344315  ...  depressed mood dragging myself through the day
# 4996  c0030193  ...                             pain living in pain
#
# [72 rows x 4 columns],             id  ...                               phrase-label
# 4997  c0424166  ...              social fear ~public~ friendly
# 4999  c2830004  ...            somnolence 14 hours of it daily
# 5000  c0344315  ...           depressed mood makes you depress
# 5001  c0393760  ...          initial insomnia keeping me awake
# 5006  c0022107  ...  irritable mood serious resting bitch face
# ...        ...  ...                                        ...
# 5167  c0022107  ...                     irritable mood asshole
# 5168  c0003467  ...                      anxiety scared/unsure
# 5177  c0917801  ...                sleeplessness got me uppppp
# 5181  c0085633  ...                       mood swings dramatic
# 5184  c0040822  ...                             tremor jitters
#
# [72 rows x 4 columns]]
# Result For Question 3
# [                   id  ...                                   phrase-label
# 1    3384011000036100  ...                            arthrotec arthrotec
# 2           166717003  ...      serum creatinine raised elevated creatine
# 3    3877011000036101  ...                                lipitor lipitor
# 5           404640003  ...                                dizziness dizzy
# 6           271681002  ...     stomach ache pain in the pit of my stomach
# ..                ...  ...                                            ...
# 536          76948002  ...      severe pain severe muscle pain in sholder
# 537          34436003  ...  haematuria blood began showing up in my urine
# 538          34840004  ...                          tendonitis tendonitis
# 542         267064002  ...             urinary retention couldn't urinate
# 543          82991003  ...   generalised aches and pains everything hurts
#
# [269 rows x 4 columns],              id  ...                                       phrase-label
# 550    49218002  ...                              hip pain hip soreness
# 551    76948002  ...                       severe pain severe back pain
# 552    68962001  ...        myalgia debilitating muscle pain in my back
# 553   449917004  ...                cramp in lower limb leg/foot cramps
# 556   224960004  ...                              tired extremely tired
# ...         ...  ...                                                ...
# 1727  161874006  ...                        heavy feeling heavy feeling
# 1728  271832001  ...  flatulence, eructation and gas pain flatulence...
# 1735   21545007  ...                                tenalgia tendonitis
# 1736   21545007  ...                                  tenalgia tenalgia
# 1737  166717003  ...        serum creatinine raised cpk mildly elevated
#
# [269 rows x 4 columns],              id  ...                                       phrase-label
# 1741   68962001  ...                      myalgia leg muscle discomfort
# 1743  429783005  ...  paraesthesia of lower extremity tingling in my...
# 1744  429783005  ...  paraesthesia of lower extremity paraesthesia o...
# 1748  235856003  ...         liver disease damaged my liver permanently
# 1752  288230000  ...  myalgia/myositis -pelvis/thigh pain in my thig...
# ...         ...  ...                                                ...
# 3663   79890006  ...                          loss of appetite anorexic
# 3672   76948002  ...                      severe pain extreme back pain
# 3674  426899007  ...    pain provoked by walking discomfort when i walk
# 3682   57676002  ...                           arthralgia aching joints
# 3691  228158008  ...                  walking disability could not walk
#
# [269 rows x 4 columns],              id  ...                                       phrase-label
# 3693   29542008  ...       uterine spasm uterus starting to have spasms
# 3694   29542008  ...                        uterine spasm uterine spasm
# 3705   24184005  ...     finding of increased blood pressure rise in bp
# 3721   29857009  ...                              chest pain chest hurt
# 3735  116289008  ...                abdominal bloating extreme bloating
# ...         ...  ...                                                ...
# 5588  248490000  ...                             bloating symptom bloat
# 5609   68962001  ...                             myalgia musclesoreness
# 5615  228158008  ...  walking disability the heel i couldn't walk on...
# 5617  299060006  ...         swelling of finger knuckles are so swollen
# 5624   62507009  ...               pins and needles tingling in my arms
#
# [269 rows x 4 columns],                      id  ...                                       phrase-label
# 5630           76948002  ...                  severe pain severe abdonimal pain
# 5642          249913002  ...                  knee stiff stiffness at left knee
# 5649           76948002  ...                  severe pain severe abdominal pain
# 5677           52613005  ...             excessive sweating pronounced sweating
# 5681           76948002  ...                severe pain severe pain in shoulder
# ...                 ...  ...                                                ...
# 7866           30989003  ...                             knee pain pain in knee
# 7872  77424011000036100  ...                                ubidecarenone cq-10
# 7878           29542008  ...              uterine spasm severe uterine cramping
# 7884          309774006  ...             weakness of limb weakness in his knees
# 7886          288231001  ...  myalgia/myositis - lower leg soreness in calf ...
#
# [269 rows x 4 columns],               id  ...                                       phrase-label
# 7908    26544005  ...     muscle weakness strength decrease dramatically
# 7910   247323005  ...         tightness in throat tightness in my throat
# 7919    76948002  ...  severe pain severe muscle pain - especially in...
# 7931    13791008  ...                        asthenia extremely fatigued
# 7939   162352007  ...                  ringing in ear ringing in my ears
# ...          ...  ...                                                ...
# 10041   24199005  ...                          feeling agitated agitated
# 10050  399153001  ...                      vertigo vertigo like episodes
# 10052  271782001  ...                          drowsy hard to stay awake
# 10064  246636008  ...          blurred vision - hazy very blurred vision
# 10070   95891005  ...            influenza-like illness flu-like malaise
#
# [269 rows x 4 columns],               id  ...                                       phrase-label
# 10074   95891005  ...           influenza-like illness flu like synptoms
# 10082  267052005  ...                       flatulence/wind horrible gas
# 10086  285365001  ...                  pain in toe pain in toes and feet
# 10088  274663001  ...                        acute pain sudden knee pain
# 10094  386033004  ...                             neuropathy neurophathy
# ...          ...  ...                                                ...
# 12532  162076009  ...  excessive upper gastrointestinal gas general f...
# 12536   76948002  ...                   severe pain extreme pain in legs
# 12542   30989003  ...               knee pain pain in the knees and feet
# 12546  248096004  ...                lack of libido lack of sexual drive
# 12562  301345002  ...              difficulty sleeping problems sleeping
#
# [268 rows x 4 columns],               id  ...                                phrase-label
# 12568   21522001  ...      abdominal pain terrible abdominal pain
# 12574   26544005  ...      muscle weakness severe muscle weakness
# 12582   76948002  ...               severe pain severe elbow pain
# 12607  282145008  ...      unable to walk i simply could not walk
# 12611   95891005  ...       influenza-like illness fluey feelings
# ...          ...  ...                                         ...
# 14780  248491001  ...         swollen knee swelling of right knee
# 14784   69791001  ...  increased venous pressure high blood press
# 14786  285365001  ...          pain in toe toes became so painful
# 14788  247323005  ...        tightness in throat throat tightness
# 14808   62507009  ...       pins and needles tingling in my shins
#
# [268 rows x 4 columns],                       id  ...                                phrase-label
# 14818           21522001  ...         abdominal pain lower abdominal pain
# 14832          129565002  ...            myopathy extreme muscle problems
# 14840           82971005  ...    impaired mobility mobility has decreased
# 14852          249915009  ...   hand joint stiff joint stiffness in hands
# 14856          250082003  ...                 hand cramps cramps in hands
# ...                  ...  ...                                         ...
# 16970           80449002  ...     muscle fatigue muscle weariness in legs
# 16982  77436011000036106  ...          fish oil natural fish oil capsules
# 16986          386692008  ...  menorrhagia clotting, and horrible periods
# 16994   3877011000036101  ...                            lipitor liptitor
# 17005           76948002  ...      severe pain severe pain in both thighs
#
# [268 rows x 4 columns],               id  ...                                       phrase-label
# 17007   88092000  ...                     muscle atrophy losing muscular
# 17014   76948002  ...               severe pain severe back and hip pain
# 17018  131148009  ...                                     bleeding bleed
# 17026   60862001  ...                                 tinnitus tinititis
# 17042   57676002  ...           arthralgia chronic pain in all my joints
# ...          ...  ...                                                ...
# 34621   68962001  ...                             myalgia muscle fatigue
# 34636  162059005  ...     upset stomach stomach stayed upset and painful
# 34648   47933007  ...                                foot pain feet sore
# 34662  271832001  ...  flatulence, eructation and gas pain gas pains ...
# 84373   95891005  ...  influenza-like illness  fluey feelings in uppe...
#
# [268 rows x 4 columns]]
# Result for Question 2
#                               TwADR-L  AskAPatient
# Unique_phrases                 616.00      2665.00
# Unique_labels                   76.00       233.00
# Unique_phrase_label_pairs      721.00      2686.00
# Phrases with multiple labels    87.00        19.00
# Min examples per label           5.00         5.00
# Max examples per label          36.00       141.00
# Avg examples per label           9.49        11.53
